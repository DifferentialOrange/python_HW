# %%
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import ProcessPoolExecutor
from bs4 import BeautifulSoup
import requests

headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) ' +
                         'AppleWebKit/537.36 (KHTML, like Gecko) ' +
                         'Chrome/69.0.3497.100 ' +
                         'Safari/537.36' +
                         'OPR/56.0.3051.99'}

url_head = 'https://www.metacritic.com'

# %% [markdown]
# Список URL'ов по каждой доступной на MetaCritic платформе

# %%
platforms = {'PlayStation 4' : 'https://www.metacritic.com/browse/games/release-date/available/ps4/date',
            'Xbox One' : 'https://www.metacritic.com/browse/games/release-date/available/xboxone/date',
            'Switch' : 'https://www.metacritic.com/browse/games/release-date/available/switch/date',
            'PC' : 'https://www.metacritic.com/browse/games/release-date/available/pc/date',
            'Wii U': 'https://www.metacritic.com/browse/games/release-date/available/wii-u/date',
            '3DS' : 'https://www.metacritic.com/browse/games/release-date/available/3ds/date',
            'PlayStation Vita' : 'https://www.metacritic.com/browse/games/release-date/available/vita/date',
            'iOS' : 'https://www.metacritic.com/browse/games/release-date/available/ios/date',
            'PlayStation 3' : 'https://www.metacritic.com/browse/games/release-date/available/ps3/date',
            'PlayStation 2' : 'https://www.metacritic.com/browse/games/release-date/available/ps2/date',
            'PlayStation' : 'https://www.metacritic.com/browse/games/release-date/available/ps/date',
            'Xbox 360' : 'https://www.metacritic.com/browse/games/release-date/available/xbox360/date',
            'Xbox' : 'https://www.metacritic.com/browse/games/release-date/available/xbox/date',
            'Wii' : 'https://www.metacritic.com/browse/games/release-date/available/wii/date',
            'DS' : 'https://www.metacritic.com/browse/games/release-date/available/ds/date',
            'GameCube' : 'https://www.metacritic.com/browse/games/release-date/available/gamecube/date',
            'Nintendo 64' : 'https://www.metacritic.com/browse/games/release-date/available/n64/date',
            'Game Boy Advance' : 'https://www.metacritic.com/browse/games/release-date/available/gba/date',
            'PSP' : 'https://www.metacritic.com/browse/games/release-date/available/psp/date',
            'Dreamcast' : 'https://www.metacritic.com/browse/games/release-date/available/dreamcast/date'}

# %% [markdown]
# Маппер для параллельного обкачивания информации

# %%
def pool_mapper(urls, func, max_workers=32):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
            return executor.map(func, urls)

# %% [markdown]
# Функции для выкачивания информации об играх по их URL

# %%
def get_data(url):
    try:
        html = requests.get(url, headers=headers).text
        soup = BeautifulSoup(html, 'html.parser')
    
        name = soup.select_one('.hover_none').text.lstrip().rstrip()
        platform = soup.find('span', class_='platform').text.lstrip().rstrip()
        date = soup.select_one('li.summary_detail.release_data').find(class_="data").text
    
        return [name, platform, date]

    except:
        print('Exception in ' + url)
        return []

    
def get_data_by_list(game_url_list, step=100, time_sleep=5):
    data = []

    for i in range(0, len(game_url_list), step):
        url_cut = game_url_list[i: min(i + step, len(game_url_list))]

        for item in pool_mapper(url_cut, get_data):
            if len(item) > 0:
                data.append(item)
        time.sleep(time_sleep)
        
    return data

# %% [markdown]
# Функции для выкачивания списка URL'ов игр

# %%
def get_url_from_pages(page_url):
    html = requests.get(page_url, headers=headers).text
    soup = BeautifulSoup(html, 'html.parser')
    
    title_list = soup.findAll('div', class_="basic_stat product_title")
    
    url_list = []
    for item in title_list:
        url_end = item.find('a', href=True)['href']
        url_list.append(url_head + url_end)
        
    return url_list

def get_url_lists(start_urt):
    list_url_lists = []

    url = start_urt
    while True:
        list_url_lists.append(url)
        html = requests.get(url, headers=headers).text
        soup = BeautifulSoup(html, 'html.parser')
    
        res_flipper = soup.find('span', class_='flipper next')
        if res_flipper is None:
            break
        res_url = res_flipper.find('a')
        if res_url is None:
            break
        next_url_end = res_url['href']
        url = url_head + next_url_end

    return list_url_lists

# %% [markdown]
# Получить всю библиотеку платформы

# %%
def analyze(xlsx_name, start_url):
    list_url_lists = get_url_lists(start_url)
    
    game_url_list = [item for url_list in pool_mapper(list_url_lists, get_url_from_pages, 
                        max_workers=len(list_url_lists)) for item in url_list]

    data = get_data_by_list(game_url_list)
        
    df = pd.DataFrame(data)
    df = df.drop_duplicates()
    df = df.rename(index=str, columns={0: "Name", 1: "Platform", 2: "Date_of_Release"})
    
    df.to_excel(xlsx_name + ".xlsx")
    
    return df

# %%
# %%time

analyze('GameCube', platforms['GameCube'])
# Out:
# CPU times: user 51.8 s, sys: 2.15 s, total: 53.9 s
# Wall time: 1min 56s
#                                                   Name  Platform  \
# 0                                        Madden NFL 08  GameCube
# 1                                          Ratatouille  GameCube
# 2                                            Surf's Up  GameCube
# 3                        Backyard Sports Baseball 2007  GameCube
# 4                          Disney's Meet the Robinsons  GameCube
# 5                                                 TMNT  GameCube
# 6                              Zatch Bell! Mamodo Fury  GameCube
# 7               The Legend of Zelda: Twilight Princess  GameCube
# 8                          Shrek Smash n' Crash Racing  GameCube
# 9                                  Tomb Raider: Legend  GameCube
# 10                                     Bionicle Heroes  GameCube
# 11                                          Happy Feet  GameCube
# 12                               Need for Speed Carbon  GameCube
# 13             Tom Clancy's Splinter Cell Double Agent  GameCube
# 14                                        Flushed Away  GameCube
# 15                Nicktoons: Battle for Volcano Island  GameCube
# 16                                    The Sims 2: Pets  GameCube
# 17   SpongeBob SquarePants: Creature from the Krust...  GameCube
# 18                The Legend of Spyro: A New Beginning  GameCube
# 19                          Avatar: The Last Airbender  GameCube
# 20                                      FIFA 07 Soccer  GameCube
# 21                            Naruto: Clash of Ninja 2  GameCube
# 22                The Grim Adventures of Billy & Mandy  GameCube
# 23                                Baten Kaitos Origins  GameCube
# 24                                         Open Season  GameCube
# 25                             Bratz: Forever Diamondz  GameCube
# 26                        One Piece: Pirates' Carnival  GameCube
# 27             Lego Star Wars II: The Original Trilogy  GameCube
# 28                          One Piece: Grand Adventure  GameCube
# 29                                 Pac-Man World Rally  GameCube
# ..                                                 ...       ...
# 515                    Jeremy McGrath Supercross World  GameCube
# 516                             All-Star Baseball 2003  GameCube
# 517                                     Smashing Drive  GameCube
# 518                   18 Wheeler: American Pro Trucker  GameCube
# 519                                         NBA Street  GameCube
# 520                           Sonic Adventure 2 Battle  GameCube
# 521                                        Dark Summit  GameCube
# 522              ESPN International Winter Sports 2002  GameCube
# 523                                 NBA Courtside 2002  GameCube
# 524                                         Cel Damage  GameCube
# 525            Universal Studios Theme Parks Adventure  GameCube
# 526                             The Simpsons Road Rage  GameCube
# 527                          NFL Quarterback Club 2002  GameCube
# 528                            Super Smash Bros. Melee  GameCube
# 529                                             Pikmin  GameCube
# 530                                         SSX Tricky  GameCube
# 531                            XGIII: Extreme G Racing  GameCube
# 532                                   FIFA Soccer 2002  GameCube
# 533                                         Crazy Taxi  GameCube
# 534                         Dave Mirra Freestyle BMX 2  GameCube
# 535                                    Madden NFL 2002  GameCube
# 536                              Wave Race: Blue Storm  GameCube
# 537                                    Luigi's Mansion  GameCube
# 538                             All-Star Baseball 2002  GameCube
# 539                                  Super Monkey Ball  GameCube
# 540                                     NHL Hitz 20-02  GameCube
# 541                                  Batman: Vengeance  GameCube
# 542                            Disney's Tarzan Untamed  GameCube
# 543                           Tony Hawk's Pro Skater 3  GameCube
# 544          Star Wars Rogue Leader: Rogue Squadron II  GameCube
#
#     Date_of_Release
# 0      Aug 14, 2007
# 1      Jun 26, 2007
# 2      Jun  1, 2007
# 3      Apr  3, 2007
# 4      Mar 27, 2007
# 5      Mar 20, 2007
# 6      Dec 12, 2006
# 7      Dec 11, 2006
# 8      Nov 21, 2006
# 9      Nov 14, 2006
# 10     Nov 14, 2006
# 11     Nov 14, 2006
# 12     Oct 31, 2006
# 13     Oct 26, 2006
# 14     Oct 24, 2006
# 15     Oct 24, 2006
# 16     Oct 17, 2006
# 17     Oct 16, 2006
# 18     Oct 10, 2006
# 19     Oct 10, 2006
# 20     Oct  3, 2006
# 21     Sep 26, 2006
# 22     Sep 25, 2006
# 23     Sep 25, 2006
# 24     Sep 19, 2006
# 25     Sep 18, 2006
# 26     Sep 12, 2006
# 27     Sep 12, 2006
# 28     Aug 29, 2006
# 29     Aug 22, 2006
# ..              ...
# 515    Feb 27, 2002
# 516    Feb 25, 2002
# 517    Feb 18, 2002
# 518    Feb 18, 2002
# 519    Feb 17, 2002
# 520    Feb 11, 2002
# 521    Feb  4, 2002
# 522    Feb  4, 2002
# 523    Jan 13, 2002
# 524    Jan  7, 2002
# 525    Dec 18, 2001
# 526    Dec 17, 2001
# 527    Dec 14, 2001
# 528    Dec  2, 2001
# 529    Dec  2, 2001
# 530    Dec  2, 2001
# 531    Nov 27, 2001
# 532    Nov 21, 2001
# 533    Nov 17, 2001
# 534    Nov 17, 2001
# 535    Nov 17, 2001
# 536    Nov 17, 2001
# 537    Nov 17, 2001
# 538    Nov 17, 2001
# 539    Nov 17, 2001
# 540    Nov 17, 2001
# 541    Nov 17, 2001
# 542    Nov 17, 2001
# 543    Nov 13, 2001
# 544    Nov  9, 2001
#
# [545 rows x 3 columns]
